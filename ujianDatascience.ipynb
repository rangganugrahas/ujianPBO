# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
a = 3
b = 2
c = 4
d = 5
e = 6
f = 1
g = 5
h = 6
i = 3
j = 2
k = 2
l = 1
m = 3
n = 1
o = 5
dadu = 6
dadu1 =12
a11 = 9
b11 = 11
c11 = 3
d11 = 6
e11 = 2
f1 = 4
g1 = 9
h1 = 12
i1 = 10
j1 = 8
k1 = 2
l1 = 6
m1 = 3
n1 = 4
o1 = 9
p1 = 8
q1 = 5
r1 = 6
s1 = 11
t1 = 10

h1 = a/dadu
h2 = b/dadu
h3 = c/dadu
h4 = d/dadu
h5 = e/dadu
h6 = f/dadu
h7 = g/dadu
h8 = h/dadu
h9 = i/dadu
h10 = j/dadu
h11 = k/dadu
h12 = l/dadu
h13 = m/dadu
h14 = n/dadu
h15 = o/dadu
print("========soal 1 =================")
print("=======Dua buah dadu dilempar======")
print("percobaan 1 = " +str(h1))
print("percobaan 2 = " +str(h2))
print("percobaan 3 = " +str(h3))
print("percobaan 4 = " +str(h4))
print("percobaan 5 = " +str(h5))
print("percobaan 6 = " +str(h6))
print("percobaan 7 = " +str(h7))
print("percobaan 8 = " +str(h8))
print("percobaan 9 = " +str(h9))
print("percobaan 10 = " +str(h10))
print("percobaan 11 = " +str(h11))
print("percobaan 12 = " +str(h12))
print("percobaan 13 = " +str(h13))
print("percobaan 14 = " +str(h14))
print("percobaan 15 = " +str(h15))
print("")
hasil1 = h1 + h2 + h3 + h4 + h5 + h6 + h7 + h8 + h9 + h10 + h11 + h12 + h13 + h14 + h15
print("Total nilai Probabilitas Semua percobaan = " +str(hasil1))
hasil2 = h1 + h2 + h3 + h6  + h9 + h10 + h11 + h12 + h13 + h14 
print("Total pelemparan dadu yang memiliki nilai < 5 = " +str(hasil2))

print()
print()
print("=======Dua buah dadu dilempar======")

j1 = a11/dadu1
j2 = b11/dadu1
j3 = c11/dadu1
j4 = d11/dadu1
j5 = e11/dadu1
j6 = f1/dadu1
j7 = g1/dadu1
j8 = h1/dadu1
j9 = i1/dadu1
j10 = j1/dadu1
j11 = k1/dadu1
j12 = l1/dadu1
j13 = m1/dadu1
j14 = n1/dadu1
j15 = o1/dadu1
j16 = p1/dadu1
j17 = q1/dadu1
j18 = r1/dadu1
j19 = s1/dadu1
j20 = t1/dadu1
print("Percobaan 1 =" +str(j1))
print("Percobaan 1 =" +str(j2))
print("Percobaan 1 =" +str(j3))
print("Percobaan 1 =" +str(j4))
print("Percobaan 1 =" +str(j5))
print("Percobaan 1 =" +str(j6))
print("Percobaan 1 =" +str(j7))
print("Percobaan 1 =" +str(j8))
print("Percobaan 1 =" +str(j9))
print("Percobaan 1 =" +str(j10))
print("Percobaan 1 =" +str(j11))
print("Percobaan 1 =" +str(j12))
print("Percobaan 1 =" +str(j13))
print("Percobaan 1 =" +str(j14))
print("Percobaan 1 =" +str(j15))
print("Percobaan 1 =" +str(j16))
print("Percobaan 1 =" +str(j17))
print("Percobaan 1 =" +str(j18))
print("Percobaan 1 =" +str(j19))
print("Percobaan 1 =" +str(j20))
jj4= j4 / 6 
jj5 = j5 / 6
jj6 = j6 / 6
jj8 = j8 / 6
jj9 = j9 / 6
jj10 = j10 / 6
jj11 = j11 /6
jj12 = j12 / 6
jj14 = j14 / 6
jj16 = j16 / 6
jj18 = j18 / 6
jj20 = j20 / 6
hasil2 = j1 + j2 + j3 + j4 + j5 + j6 + j7 + j8 + j9 + j10 + j11 + j12 + j13 + j14 + j15 + j16 + j17 + j18 + j19 + j20
print()
print("Total nilai probabilitas semua percobaan = " +str(hasil2))
hasil3 = jj4 + jj5 + jj6 + jj8 + jj9 + jj10 + jj11 + jj12 + jj14 + jj16 + jj18 + jj20
print("Total pelemparan dadu yang memiliki nilai genap = " +str(hasil3))

print()
# Out:
# ========soal 1 =================
# =======Dua buah dadu dilempar======
# percobaan 1 = 0.5
# percobaan 2 = 0.3333333333333333
# percobaan 3 = 0.6666666666666666
# percobaan 4 = 0.8333333333333334
# percobaan 5 = 1.0
# percobaan 6 = 0.16666666666666666
# percobaan 7 = 0.8333333333333334
# percobaan 8 = 1.0
# percobaan 9 = 0.5
# percobaan 10 = 0.3333333333333333
# percobaan 11 = 0.3333333333333333
# percobaan 12 = 0.16666666666666666
# percobaan 13 = 0.5
# percobaan 14 = 0.16666666666666666
# percobaan 15 = 0.8333333333333334
#
# Total nilai Probabilitas Semua percobaan = 8.166666666666666
# Total pelemparan dadu yang memiliki nilai < 5 = 3.666666666666667
#
#
# =======Dua buah dadu dilempar======
# Percobaan 1 =0.75
# Percobaan 1 =0.9166666666666666
# Percobaan 1 =0.25
# Percobaan 1 =0.5
# Percobaan 1 =0.16666666666666666
# Percobaan 1 =0.3333333333333333
# Percobaan 1 =0.75
# Percobaan 1 =0.041666666666666664
# Percobaan 1 =0.8333333333333334
# Percobaan 1 =0.0625
# ...

# %%
print("===========Soal 2===========")
print("===========no1==============")
a1 = 6560860
b1 = 5950850
c1 = 12685900
d1 = 5768500
e1 = 2989000

a2 = 8782150
b2 = 6620000
c2 = 5128750
d2 = 5217300
e2 = 4820600

a3 = 8130940
b3 = 2940650
c3 = 3488200
d3 = 6930540
e3 = 4319260

a4 = 12849100
b4 = 5752200
c4 = 5128400
d4 = 3880490
e4 = 4982100

hsl1 = a1 + b1 + c1 + d1 + e1
hsl2 = a2 + b2 + c2 + d2 + e2
hsl3 = a3 + b3 + c3 + d3 + e3
hsl4 = a4 + b4 + c4 + d4 + e4
print("Total pendapatan minggu 1 = " +str(hsl1))
print("Total pendapatan minggu 2 = " +str(hsl2))
print("Total pendapatan minggu 3 = " +str(hsl3))
print("Total pendapatan minggu 4 = " +str(hsl4))
print()

plt.title("Data omset adalah ")
plt.xlabel("perusahaan")
plt.ylabel("nilai")
x =  ['Minggu 1', 'Minggu 2','Minggu 3','Minggu 4']
y = [33955110, 30568800,25809590,32592290]
plt.scatter(x, y)
plt.show()
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
indeks = ['Minggu 1', 'Minggu 2','Minggu 3','Minggu 4']
jumlah = [33955110, 30568800,25809590,32592290]
c = ['orange', 'blue']
plt.title("Data omnset adalah ")
plt.xlabel("perusahaan")
plt.ylabel("nilai")
plt.bar(indeks, jumlah, color = c)
plt.grid(True)
plt.show


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Data omset adalah ")
nama =['Minggu 1', 'Minggu 2','Minggu 3','Minggu 4']
jml =  [33955110, 30568800,25809590,32592290]
ax.pie(jml,labels=nama,autopct='%1.2f%%')
plt.show()


p1 = a1/386
p2 = b1/752
p3 = c1/1203
p4 = d1/715
p5 = e1/289
p6 = a2/454
p7 = b2/781
p8 = c2/634
p9 = d2/659
p10 = e2/411
p11 = a3/599
p12 = b3/338
p13 = c3/442
p14 = d3/872
p15 = e3/390
p16 = a4/867
p17 = b4/512
p18 = c4/650
p19 = d4/492
p20 = e4/488
print("===========no2==============")
print()
print("=====rata-rata minggu 1======")
print("buah-buahan adalah : " +str(p1))
print("Keperluan dapur adalah : " +str(p2))
print("snack dan makanan adalah : " +str(p3))
print("keperluan mandi dsb adalah : " +str(p4))
print("perlengkapan rumah tangga adalah : " +str(p5))
print()
print("=====rata-rata minggu 2======")
print("buah-buahan adalah : " +str(p6))
print("Keperluan dapur adalah : " +str(p7))
print("snack dan makanan adalah : " +str(p8))
print("keperluan mandi dsb adalah : " +str(p9))
print("perlengkapan rumah tangga adalah : " +str(p10))
print()
print("=====rata-rata minggu 3======")
print("buah-buahan adalah : " +str(p11))
print("Keperluan dapur adalah : " +str(p12))
print("snack dan makanan adalah : " +str(p13))
print("keperluan mandi dsb adalah : " +str(p14))
print("perlengkapan rumah tangga adalah : " +str(p15))
print()
print("=====rata-rata minggu 4======")
print("buah-buahan adalah : " +str(p16))
print("Keperluan dapur adalah : " +str(p17))
print("snack dan makanan adalah : " +str(p18))
print("keperluan mandi dsb adalah : " +str(p19))
print("perlengkapan rumah tangga adalah : " +str(p20))
print()
print("===========no3==============")
jp1 = 180
jp2 = 164
jp3 = 218
jp4 = 156
jp5 = 92
jp6 = 156
jp7 = 212
jp8 = 164
jp9 = 144
jp10 = 138
jp11 = 290
jp12 = 95
jp13 = 120
jp14 = 225
jp15 = 135
jp16 = 350
jp17 = 143
jp18 = 201
jp19 = 174
jp20 = 205
print()
jph1 = jp1 + jp2 + jp3 + jp4 + jp5 
jph2 = jp6 + jp7 + jp8 + jp9 + jp10 
jph3 = jp11 + jp12 + jp13 + jp14 + jp15 
jph4 = jp16 + jp17 + jp18 + jp19 + jp20


senin = jph1 * 10 / 100
senin11 = jph2 * 10 / 100
senin12 = jph3 * 10 / 100
senin13 = jph4 * 10 / 100
print("total pengunjung minggu 1  : " +str(jph1))
print("pengunjung hari senin : " +str(senin))
print("pengunjung hari selasa : " +str(senin))
print("pengunjung hari rabu : " +str(senin))
print("pengunjung hari kamis : " +str(senin))
print("pengunjung hari jumat : " +str(senin))
sabtu = jph1 * 25 / 100
sabtu11 = jph2 * 25 / 100
sabtu12 = jph3 * 25 / 100
sabtu13 = jph4 * 25 / 100
print("pengunjung hari sabtu : " +str(sabtu))
print("pengunjung hari minggu : " +str(sabtu))
senin1 = senin + senin + senin + senin + senin
sabtu1 = sabtu + sabtu
print("maka jumlah penduduk hari senin-jumat adalah : " +str(senin1))
print("maka jumlah penduduk hari sabtu-minggu adalah : " +str(sabtu1))
print()
print("total pengunjung minggu 2  : " +str(jph2))
print("pengunjung hari senin : " +str(senin11))
print("pengunjung hari selasa : " +str(senin11))
print("pengunjung hari rabu : " +str(senin11))
print("pengunjung hari kamis : " +str(senin11))
print("pengunjung hari jumat : " +str(senin11))
print("pengunjung hari sabtu : " +str(sabtu11))
print("pengunjung hari minggu : " +str(sabtu11))
senin21 = senin11 + senin11 + senin11 + senin11 + senin11
sabtu21 = sabtu11 + sabtu11
print("maka jumlah penduduk hari senin-jumat adalah : " +str(senin21))
print("maka jumlah penduduk hari sabtu-minggu adalah : " +str(sabtu21))
print()
print("total pengunjung minggu 3  : " +str(jph3))
print("pengunjung hari senin : " +str(senin12))
print("pengunjung hari selasa : " +str(senin12))
print("pengunjung hari rabu : " +str(senin12))
print("pengunjung hari kamis : " +str(senin12))
print("pengunjung hari jumat : " +str(senin12))
print("pengunjung hari sabtu : " +str(sabtu12))
print("pengunjung hari minggu : " +str(sabtu12))
senin22 = senin12 + senin12 + senin12 + senin12 + senin12
sabtu22 = sabtu12 + sabtu12
print("maka jumlah penduduk hari senin-jumat adalah : " +str(senin22))
print("maka jumlah penduduk hari sabtu-minggu adalah : " +str(sabtu22))
print()
print("total pengunjung minggu 4  : " +str(jph4))
print("pengunjung hari senin : " +str(senin13))
print("pengunjung hari selasa : " +str(senin13))
print("pengunjung hari rabu : " +str(senin13))
print("pengunjung hari kamis : " +str(senin13))
print("pengunjung hari jumat : " +str(senin13))
print("pengunjung hari sabtu : " +str(sabtu13))
print("pengunjung hari minggu : " +str(sabtu13))
senin23 = senin13 + senin13 + senin13 + senin13 + senin13
sabtu23 = sabtu13 + sabtu13
print("maka jumlah penduduk hari senin-jumat adalah : " +str(senin23))
print("maka jumlah penduduk hari sabtu-minggu adalah : " +str(sabtu23))
print()
hsil1 = a1 + b1 + c1 + d1 + e1
hsil2 = a2 + b2 + c2 + d2 + e2
hsil3 = a3 + b3 + c3 + d3 + e3
hsil4 = a4 + b4 + c4 + d4 + e4
senin31 = hsil1 * 10 / 100
senin32 = hsil2 * 10 / 100
senin33 = hsil3 * 10 / 100
senin34 = hsil4 * 10 / 100
sabtu31 = hsil1 * 25 / 100
sabtu32 = hsil2 * 25 / 100
sabtu33 = hsil3 * 25 / 100
sabtu34 = hsil4 * 25 / 100
print()
print("===========no4==============")
print("omset minggu 1 : " +str(hsil1))

print("omset hari senin : " +str(senin31))
print("omset hari selasa : " +str(senin31))
print("omset hari rabu : " +str(senin31))
print("omset hari kamis : " +str(senin31))
print("omset hari jumat : " +str(senin31))

print("omset hari sabtu : " +str(sabtu31))
print("omset hari minggu : " +str(sabtu31))
senin3 = senin31 + senin31 + senin31 + senin31 + senin31
sabtu3 = sabtu31 + sabtu31
print("maka jumlah penduduk hari senin-jumat adalah : " +str(senin3))
print("maka jumlah penduduk hari sabtu-minggu adalah : " +str(sabtu3))
print()
print("omset minggu 2 : " +str(hsil2))

print("omset hari senin : " +str(senin32))
print("omset hari selasa : " +str(senin32))
print("omset hari rabu : " +str(senin32))
print("omset hari kamis : " +str(senin32))
print("omset hari jumat : " +str(senin32))

print("omset hari sabtu : " +str(sabtu32))
print("omset hari minggu : " +str(sabtu32))
senin4 = senin32 + senin32 + senin32 + senin32 + senin32
sabtu4 = sabtu32 + sabtu32
print("maka jumlah penduduk hari senin-jumat adalah : " +str(senin4))
print("maka jumlah penduduk hari sabtu-minggu adalah : " +str(sabtu4))
print()
print("omset minggu 3 : " +str(hsil3))

print("omset hari senin : " +str(senin33))
print("omset hari selasa : " +str(senin33))
print("omset hari rabu : " +str(senin33))
print("omset hari kamis : " +str(senin33))
print("omset hari jumat : " +str(senin33))

print("omset hari sabtu : " +str(sabtu33))
print("omset hari minggu : " +str(sabtu33))
senin5 = senin33 + senin33 + senin33 + senin33 + senin33
sabtu5 = sabtu33 + sabtu33
print("maka jumlah penduduk hari senin-jumat adalah : " +str(senin5))
print("maka jumlah penduduk hari sabtu-minggu adalah : " +str(sabtu5))
print()
print("omset minggu 4 : " +str(hsil4))

print("omset hari senin : " +str(senin34))
print("omset hari selasa : " +str(senin34))
print("omset hari rabu : " +str(senin34))
print("omset hari kamis : " +str(senin34))
print("omset hari jumat : " +str(senin34))

print("omset hari sabtu : " +str(sabtu34))
print("omset hari minggu : " +str(sabtu34))
senin6 = senin34 + senin34 + senin34 + senin34 + senin34
sabtu6 = sabtu34 + sabtu34
print("maka jumlah penduduk hari senin-jumat adalah : " +str(senin6))
print("maka jumlah penduduk hari sabtu-minggu adalah : " +str(sabtu6))
print()
hslj1 = a1 + a2 + a3 + a4
hslj2 = b1 + b2 + b3 + b4
hslj3 = c1 + c2 + c3 + c4
hslj4 = d1 + d2 + d3 + d4
hslj5 = e1 + e2 + e3 + e4
x1 =386
x2 =752
x3 =1203
x4 =715
x5 =289
xx1 =454
xx2=781
xx3=634
xx4=659
xx5=411
xxx1=599
xxx2=338
xxx3=442
xxx4=872
xxx5=390
xxxx1=867
xxxx2=512
xxxx3=650
xxxx4=492
xxxx5=488
hslj6 = x1 + xx1 + xxx1 + xxxx1
hslj7 = x2 + xx2 + xxx2 + xxxx2
hslj8 = x3 + xx3 + xxx3 + xxxx3
hslj9 = x4 + xx4 + xxx4 + xxxx4
hslj10 = x5 + xx5 + xxx5 + xxxx5
print("================no5===================")

print("==========pendapatan=======")
print("jumlah pendapatan junction buah-buahan perminggu  :" +str(hslj1))
print("jumlah pendapatan junction Keperluan dapur perminggu  :" +str(hslj2))
print("jumlah pendapatan junction snack dan makanan perminggu  :" +str(hslj3))
print("jumlah pendapatan junction keperluan mandi dsb perminggu  :" +str(hslj4))
print("jumlah pendapatan junction perlengkapan rumah tangga perminggu  :" +str(hslj5))
print()
print("==========penjualan========")
print("jumlah penjualan junction buah-buahan perminggu  :" +str(hslj1))
print("jumlah penjualan junction Keperluan dapur perminggu  :" +str(hslj2))
print("jumlah penjualan junction snack dan makanan perminggu  :" +str(hslj3))
print("jumlah penjualan junction keperluan mandi dsb perminggu  :" +str(hslj4))
print("jumlah penjualan junction perlengkapan rumah tangga perminggu  :" +str(hslj5))
# Out:
# ===========Soal 2===========
# ===========no1==============
# Total pendapatan minggu 1 = 33955110
# Total pendapatan minggu 2 = 30568800
# Total pendapatan minggu 3 = 25809590
# Total pendapatan minggu 4 = 32592290
# ===========no2==============
#
# =====rata-rata minggu 1======
# buah-buahan adalah : 16997.04663212435
# Keperluan dapur adalah : 7913.364361702128
# snack dan makanan adalah : 10545.220282626766
# keperluan mandi dsb adalah : 8067.832167832168
# perlengkapan rumah tangga adalah : 10342.560553633219
#
# =====rata-rata minggu 2======
# buah-buahan adalah : 19343.942731277533
# Keperluan dapur adalah : 8476.312419974392
# snack dan makanan adalah : 8089.511041009464
# keperluan mandi dsb adalah : 7916.995447647952
# perlengkapan rumah tangga adalah : 11728.953771289538
#
# =====rata-rata minggu 3======
# buah-buahan adalah : 13574.190317195325
# Keperluan dapur adalah : 8700.147928994083
# snack dan makanan adalah : 7891.85520361991
# ...
